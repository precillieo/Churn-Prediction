# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline 
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split

# %%
dsn_train= pd.read_csv("Train.csv")
dsn_test= pd.read_csv("Test (1).csv")
dsn_train
# Out:
#                                          user_id       REGION        TENURE  \
# 0       dcf68cc2fb515ccad7d8b9b3bd80ee2a4b270063  SAINT-LOUIS  K > 24 month
# 1       71c44b5ba328db5c4192a80f7cf8f244d9350ed0          NaN  K > 24 month
# 2       ce46411b1526c94f20a383b8cb188f8d27f82a0a  TAMBACOUNDA  K > 24 month
# 3       f467cdb6669818373c26c2bad44e01ba66f97d21       FATICK  K > 24 month
# 4       ec45e1a1888a32b5dcce0954cfec20c6e037db31       FATICK  K > 24 month
# ...                                          ...          ...           ...
# 399995  a892ad4ed0eda8dc721733200c47147763b183ec  TAMBACOUNDA  K > 24 month
# 399996  13daa3a651bf0192a413b339c4766aeafc6d1636          NaN  K > 24 month
# 399997  767f596aee426962f7d92f4de8d7b232cdc17568          NaN  K > 24 month
# 399998  b831e4d3b59a1e294e9e0a2aab391bc12d50845c          NaN  K > 24 month
# 399999  a80e3a164986e489102cfb538fa62e16ecc28adf          NaN  K > 24 month
#
# ...

# %%
dsn_test
# Out:
#                                         user_id       REGION         TENURE  \
# 0      af900d87e73b7ff6509d2203df4704a98aa5f2a6          NaN   K > 24 month
# 1      5335efd940280b82143272275637d1e65d37eadb          NaN   K > 24 month
# 2      a581f4fa08677c26f83f643248c667e241043086          NaN   K > 24 month
# 3      64f67177d0775262b8087a9e2e3b8061b6324ae6        DAKAR   K > 24 month
# 4      0d6009a4594c4be22449b8d9cc01a0bcea98faea        DAKAR   K > 24 month
# ...                                         ...          ...            ...
# 99995  c6bcb3336795a18eb6c0bc7e19078a0704ef4d7e        LOUGA   K > 24 month
# 99996  a44b4e44dc70115ed5bf971ebb4193dd536e87f0  TAMBACOUNDA   K > 24 month
# 99997  a2f84faffbc995bd0e2d726fa4ffdb93f11646ed          NaN  I 18-21 month
# 99998  afa76e894df4201fc77eb714de7d1f262299611a        THIES   K > 24 month
# 99999  c08a2d84b87c1f5d4bb318114f508b77aa8e2663        MATAM   K > 24 month
#
# ...

# %%
dsn_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 400000 entries, 0 to 399999
# Data columns (total 19 columns):
# user_id           400000 non-null object
# REGION            242480 non-null object
# TENURE            400000 non-null object
# MONTANT           259723 non-null float64
# FREQUENCE_RECH    259723 non-null float64
# REVENUE           265337 non-null float64
# ARPU_SEGMENT      265337 non-null float64
# FREQUENCE         265337 non-null float64
# DATA_VOLUME       203146 non-null float64
# ON_NET            254181 non-null float64
# ORANGE            233683 non-null float64
# TIGO              160614 non-null float64
# ZONE1             31690 non-null float64
# ZONE2             25513 non-null float64
# MRG               400000 non-null object
# REGULARITY        400000 non-null int64
# TOP_PACK          232671 non-null object
# FREQ_TOP_PACK     232671 non-null float64
# CHURN             400000 non-null int64
# dtypes: float64(12), int64(2), object(5)
# ...

# %%
dsn_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 18 columns):
# user_id           100000 non-null object
# REGION            60707 non-null object
# TENURE            100000 non-null object
# MONTANT           65049 non-null float64
# FREQUENCE_RECH    65049 non-null float64
# REVENUE           66510 non-null float64
# ARPU_SEGMENT      66510 non-null float64
# FREQUENCE         66510 non-null float64
# DATA_VOLUME       50662 non-null float64
# ON_NET            63617 non-null float64
# ORANGE            58800 non-null float64
# TIGO              40212 non-null float64
# ZONE1             7680 non-null float64
# ZONE2             6422 non-null float64
# MRG               100000 non-null object
# REGULARITY        100000 non-null int64
# TOP_PACK          58297 non-null object
# FREQ_TOP_PACK     58297 non-null float64
# dtypes: float64(12), int64(1), object(5)
# memory usage: 11.8+ MB

# %%
dsn_train.describe()
# Out:
#              MONTANT  FREQUENCE_RECH        REVENUE   ARPU_SEGMENT  \
# count  259723.000000   259723.000000  265337.000000  265337.000000
# mean     5522.971346       11.503733    5505.487757    1835.167658
# std      7099.640630       13.275514    7175.802367    2391.929290
# min        20.000000        1.000000       1.000000       0.000000
# 25%      1000.000000        2.000000    1000.000000     333.000000
# 50%      3000.000000        6.000000    3000.000000    1000.000000
# 75%      7300.000000       15.000000    7340.000000    2447.000000
# max    226550.000000      133.000000  233413.000000   77804.000000
#
#            FREQUENCE    DATA_VOLUME         ON_NET         ORANGE  \
# count  265337.000000  203146.000000  254181.000000  233683.000000
# mean       13.951835    3369.763441     275.917586      95.532927
# std        14.679943   12281.867504     873.593034     204.733272
# min         1.000000       0.000000       0.000000       0.000000
# ...

# %%
dsn_test.describe()
# Out:
#              MONTANT  FREQUENCE_RECH        REVENUE  ARPU_SEGMENT  \
# count   65049.000000    65049.000000   66510.000000  66510.000000
# mean     5545.613630       11.545051    5518.341663   1839.453676
# std      7123.955226       13.271270    7177.840304   2392.609422
# min        25.000000        1.000000       1.000000      0.000000
# 25%      1000.000000        2.000000    1000.000000    333.000000
# 50%      3000.000000        7.000000    3000.000000   1000.000000
# 75%      7400.000000       16.000000    7399.000000   2466.000000
# max    201500.000000      120.000000  181135.000000  60378.000000
#
#           FREQUENCE    DATA_VOLUME        ON_NET        ORANGE          TIGO  \
# count  66510.000000   50662.000000  63617.000000  58800.000000  40212.000000
# mean      13.979973    3357.428033    279.370703     94.900799     23.459291
# std       14.655983   10515.256185    870.773904    201.962296     66.932661
# ...

# %%
dsn_train.isnull().sum()
# Out:
# user_id                0
# REGION            157520
# TENURE                 0
# MONTANT           140277
# FREQUENCE_RECH    140277
# REVENUE           134663
# ARPU_SEGMENT      134663
# FREQUENCE         134663
# DATA_VOLUME       196854
# ON_NET            145819
# ORANGE            166317
# TIGO              239386
# ZONE1             368310
# ZONE2             374487
# MRG                    0
# REGULARITY             0
# TOP_PACK          167329
# FREQ_TOP_PACK     167329
# CHURN                  0
# dtype: int64

# %%
dsn_test.isnull().sum()
# Out:
# user_id               0
# REGION            39293
# TENURE                0
# MONTANT           34951
# FREQUENCE_RECH    34951
# REVENUE           33490
# ARPU_SEGMENT      33490
# FREQUENCE         33490
# DATA_VOLUME       49338
# ON_NET            36383
# ORANGE            41200
# TIGO              59788
# ZONE1             92320
# ZONE2             93578
# MRG                   0
# REGULARITY            0
# TOP_PACK          41703
# FREQ_TOP_PACK     41703
# dtype: int64

# %%
dsn_train.corr()
# Out:
#                  MONTANT  FREQUENCE_RECH   REVENUE  ARPU_SEGMENT  FREQUENCE  \
# MONTANT         1.000000        0.800385  0.979041      0.979041   0.781164
# FREQUENCE_RECH  0.800385        1.000000  0.807405      0.807405   0.956262
# REVENUE         0.979041        0.807405  1.000000      1.000000   0.791627
# ARPU_SEGMENT    0.979041        0.807405  1.000000      1.000000   0.791627
# FREQUENCE       0.781164        0.956262  0.791627      0.791627   1.000000
# DATA_VOLUME     0.308343        0.165226  0.312915      0.312915   0.181491
# ON_NET          0.327857        0.402383  0.331850      0.331850   0.392656
# ORANGE          0.667531        0.522649  0.670220      0.670220   0.475057
# TIGO            0.427289        0.348092  0.425376      0.425377   0.311898
# ZONE1           0.350551        0.126573  0.355228      0.355228   0.113051
# ZONE2           0.407973        0.160979  0.377622      0.377623   0.164952
# ...

# %%
dsn_test.REGION.value_counts()
# Out:
# DAKAR          23998
# THIES           8301
# SAINT-LOUIS     5657
# LOUGA           4616
# KAOLACK         4542
# DIOURBEL        3041
# TAMBACOUNDA     2596
# KAFFRINE        1940
# KOLDA           1775
# FATICK          1656
# MATAM           1411
# ZIGUINCHOR      1006
# SEDHIOU          126
# KEDOUGOU          42
# Name: REGION, dtype: int64

# %%
dsn_train["REGION"]= dsn_train["REGION"].fillna("DAKAR", axis= 0)

# %%
dsn_test["REGION"]= dsn_test["REGION"].fillna("DAKAR", axis= 0)
dsn_test.isnull().sum()
# Out:
# user_id               0
# REGION                0
# TENURE                0
# MONTANT           34951
# FREQUENCE_RECH    34951
# REVENUE           33490
# ARPU_SEGMENT      33490
# FREQUENCE         33490
# DATA_VOLUME       49338
# ON_NET            36383
# ORANGE            41200
# TIGO              59788
# ZONE1             92320
# ZONE2             93578
# MRG                   0
# REGULARITY            0
# TOP_PACK          41703
# FREQ_TOP_PACK     41703
# dtype: int64

# %%
dsn_train["MONTANT"].value_counts()
# Out:
# 500.0      21173
# 1000.0     15519
# 1500.0      8976
# 2000.0      8566
# 200.0       7545
#            ...
# 3210.0         1
# 46350.0        1
# 15065.0        1
# 11598.0        1
# 4096.0         1
# Name: MONTANT, Length: 2421, dtype: int64

# %%
dsn_test["MONTANT"]= dsn_test["MONTANT"].fillna(dsn_test["MONTANT"].mean(), axis= 0)

# %%
dsn_train["MONTANT"]= dsn_train["MONTANT"].fillna(dsn_train["MONTANT"].mean(), axis= 0)

# %%
dsn_train.FREQUENCE_RECH.value_counts()
# Out:
# 1.0      40912
# 2.0      26222
# 3.0      20378
# 4.0      16477
# 5.0      13854
#          ...
# 106.0        1
# 108.0        1
# 118.0        1
# 105.0        1
# 114.0        1
# Name: FREQUENCE_RECH, Length: 111, dtype: int64

# %%
dsn_train["FREQUENCE_RECH"]= dsn_train["FREQUENCE_RECH"].fillna(dsn_train["FREQUENCE_RECH"].mean(), axis= 0)

# %%
dsn_test["FREQUENCE_RECH"]= dsn_test["FREQUENCE_RECH"].fillna(dsn_test["FREQUENCE_RECH"].mean(), axis= 0)

# %%
dsn_train.REVENUE.value_counts()
# Out:
# 500.0      10984
# 1000.0      6921
# 1500.0      3800
# 200.0       3780
# 2000.0      3384
#            ...
# 24088.0        1
# 18518.0        1
# 51857.0        1
# 19791.0        1
# 40009.0        1
# Name: REVENUE, Length: 23760, dtype: int64

# %%
dsn_test["REVENUE"]= dsn_test["REVENUE"].fillna(dsn_test["REVENUE"].mean(), axis= 0)

# %%
dsn_train["REVENUE"]= dsn_train["REVENUE"].fillna(dsn_train["REVENUE"].mean(), axis= 0)

# %%
dsn_test["ARPU_SEGMENT"]= dsn_test["ARPU_SEGMENT"].fillna(dsn_test["ARPU_SEGMENT"].mean(), axis= 0)

# %%
dsn_train["ARPU_SEGMENT"]= dsn_train["ARPU_SEGMENT"].fillna(dsn_train["ARPU_SEGMENT"].mean(), axis= 0)

# %%
dsn_test["FREQUENCE"]= dsn_test["FREQUENCE"].fillna(dsn_test["FREQUENCE"].mean(), axis= 0)

# %%
dsn_train["FREQUENCE"]= dsn_train["FREQUENCE"].fillna(dsn_train["FREQUENCE"].mean(), axis= 0)

# %%
dsn_train["DATA_VOLUME"].value_counts()
# Out:
# 0.0        59222
# 1.0         7700
# 2.0         2447
# 3.0         1388
# 1024.0       985
#            ...
# 14028.0        1
# 45729.0        1
# 22863.0        1
# 11431.0        1
# 26512.0        1
# Name: DATA_VOLUME, Length: 22229, dtype: int64

# %%
dsn_test["DATA_VOLUME"]= dsn_test["DATA_VOLUME"].fillna(dsn_test["DATA_VOLUME"].mean(), axis= 0)

# %%
dsn_train["DATA_VOLUME"]= dsn_train["DATA_VOLUME"].fillna(dsn_train["DATA_VOLUME"].mean(), axis= 0)
dsn_train.isnull().sum()
# Out:
# user_id                0
# REGION                 0
# TENURE                 0
# MONTANT                0
# FREQUENCE_RECH         0
# REVENUE                0
# ARPU_SEGMENT           0
# FREQUENCE              0
# DATA_VOLUME            0
# ON_NET            145819
# ORANGE            166317
# TIGO              239386
# ZONE1             368310
# ZONE2             374487
# MRG                    0
# REGULARITY             0
# TOP_PACK          167329
# FREQ_TOP_PACK     167329
# CHURN                  0
# dtype: int64

# %%
dsn_train["ON_NET"].value_counts()
# Out:
# 0.0        19884
# 1.0        17285
# 2.0        11091
# 3.0         7898
# 7.0         7707
#            ...
# 9188.0         1
# 10193.0        1
# 3281.0         1
# 5236.0         1
# 6172.0         1
# Name: ON_NET, Length: 5996, dtype: int64

# %%
dsn_test["ON_NET"]= dsn_test["ON_NET"].fillna(dsn_test["ON_NET"].mean(), axis= 0)

# %%
dsn_train["ON_NET"]= dsn_train["ON_NET"].fillna(dsn_train["ON_NET"].mean(), axis= 0)

# %%
dsn_test["ORANGE"]= dsn_test["ORANGE"].fillna(dsn_test["ORANGE"].mean(), axis= 0)

# %%
dsn_train["ORANGE"]= dsn_train["ORANGE"].fillna(dsn_train["ORANGE"].mean(), axis= 0)

# %%
dsn_test["TIGO"]= dsn_test["TIGO"].fillna(dsn_test["TIGO"].mean(), axis= 0)

# %%
dsn_train["TIGO"]= dsn_train["TIGO"].fillna(dsn_train["TIGO"].mean(), axis= 0)

# %%
dsn_test["ZONE1"]= dsn_test["ZONE1"].fillna(dsn_test["ZONE1"].mean(), axis= 0)

# %%
dsn_train["ZONE1"]= dsn_train["ZONE1"].fillna(dsn_train["ZONE1"].mean(), axis= 0)

# %%
dsn_test["ZONE2"]= dsn_test["ZONE2"].fillna(dsn_test["ZONE2"].mean(), axis= 0)

# %%
dsn_train["ZONE2"]= dsn_train["ZONE2"].fillna(dsn_train["ZONE2"].mean(), axis= 0)

# %%
dsn_test["TOP_PACK"].mode()
# Out:
# 0    All-net 500F=2000F;5d
# dtype: object

# %%
dsn_test["TOP_PACK"]= dsn_test["TOP_PACK"].fillna("All-net 500F=2000F;5d", axis= 0)

# %%
dsn_train["TOP_PACK"]= dsn_train["TOP_PACK"].fillna("All-net 500F=2000F;5d", axis= 0)

# %%
dsn_test["FREQ_TOP_PACK"]= dsn_test["FREQ_TOP_PACK"].fillna(dsn_test["FREQ_TOP_PACK"].mean(), axis= 0)
dsn_test.isnull().sum()
# Out:
# user_id           0
# REGION            0
# TENURE            0
# MONTANT           0
# FREQUENCE_RECH    0
# REVENUE           0
# ARPU_SEGMENT      0
# FREQUENCE         0
# DATA_VOLUME       0
# ON_NET            0
# ORANGE            0
# TIGO              0
# ZONE1             0
# ZONE2             0
# MRG               0
# REGULARITY        0
# TOP_PACK          0
# FREQ_TOP_PACK     0
# dtype: int64

# %%
dsn_train["FREQ_TOP_PACK"]= dsn_train["FREQ_TOP_PACK"].fillna(dsn_train["FREQ_TOP_PACK"].mean(), axis= 0)
dsn_train.isnull().sum()
# Out:
# user_id           0
# REGION            0
# TENURE            0
# MONTANT           0
# FREQUENCE_RECH    0
# REVENUE           0
# ARPU_SEGMENT      0
# FREQUENCE         0
# DATA_VOLUME       0
# ON_NET            0
# ORANGE            0
# TIGO              0
# ZONE1             0
# ZONE2             0
# MRG               0
# REGULARITY        0
# TOP_PACK          0
# FREQ_TOP_PACK     0
# CHURN             0
# dtype: int64

# %%
col= ("user_id","REGION","TENURE","MRG","TOP_PACK")
for x in col:
    le= LabelEncoder()
    dsn_train[x]= le.fit_transform(dsn_train[x].values)
dsn_train.dtypes
# Out:
# user_id             int32
# REGION              int32
# TENURE              int32
# MONTANT           float64
# FREQUENCE_RECH    float64
# REVENUE           float64
# ARPU_SEGMENT      float64
# FREQUENCE         float64
# DATA_VOLUME       float64
# ON_NET            float64
# ORANGE            float64
# TIGO              float64
# ZONE1             float64
# ZONE2             float64
# MRG                 int32
# REGULARITY          int64
# TOP_PACK            int32
# FREQ_TOP_PACK     float64
# CHURN               int64
# dtype: object

# %%
cols= ("user_id", "REGION", "TENURE","MRG","TOP_PACK")
for y in cols:
    le= LabelEncoder()
    dsn_test[y]= le.fit_transform(dsn_test[y].values)
dsn_test.dtypes
# Out:
# user_id             int32
# REGION              int32
# TENURE              int32
# MONTANT           float64
# FREQUENCE_RECH    float64
# REVENUE           float64
# ARPU_SEGMENT      float64
# FREQUENCE         float64
# DATA_VOLUME       float64
# ON_NET            float64
# ORANGE            float64
# TIGO              float64
# ZONE1             float64
# ZONE2             float64
# MRG                 int32
# REGULARITY          int64
# TOP_PACK            int32
# FREQ_TOP_PACK     float64
# dtype: object

# %%
X= dsn_train.drop("CHURN", axis= 1)
y= dsn_train["CHURN"]

# %%
train_x,val_x, train_y, val_y= train_test_split(X,y, test_size= 20, random_state= 0)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import log_loss

# %%
Ld= LinearDiscriminantAnalysis()
Ld.fit(train_x, train_y)
pd= Ld.predict_proba(val_x)[:,1]
print("LD:", log_loss(val_y, pd))

# %%
cv= cross_val_score(Ld, X,y, cv=5)
cv

# %%
gbr= GradientBoostingClassifier(learning_rate= 0.01,n_estimators= 100, random_state= 0)
gbr.fit(train_x, train_y)
preds= gbr.predict_proba(val_x)[:,1]
print("gbr result;", log_loss(val_y, preds))

# %%
#results= []
#names= []
#for name, model in models:
    #model.fit(train_x, train_y)
    #pred= model.predict_proba(val_x)[:,1]
    #score= log_loss(val_y, pred)
    #results.append(score)
    #names.append(name)
    #msg= "%s: %f" %(name,score)
    #print(msg)

# %%
#from sklearn.svm import SVC
#svm= SVC(kernel= "linear", C= 0.025, random_state= 101)
#svm.fit(train_x, train_y)
#pred= svm.predict_proba(val_x)[:,1]
#print("score:", log_loss(val_y, pred))

# %%
mode= LinearDiscriminantAnalysis()
mode.fit(X, y)
test_yhat = mode.predict_proba(dsn_test)[:,1]

# %%
submission= pd.read_csv("sample_submission.csv")
submission

# %%
submission.CHURN= test_yhat
submission

# %%
submission.to_csv("expresso.csv", index= False)
